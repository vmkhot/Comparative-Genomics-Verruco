# %%
import pandas as pd

# %%
gtdb_df = pd.read_csv('bac120_metadata_r220.tsv.gz', compression='gzip', engine='python',sep='\t')
gtdb_df

# %% [markdown]
# Genomes to replace:
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Opitutales;f__JAIRLM01;g__JAIRLM01;s__JAIRLM01 sp031268795
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Opitutales;f__JAIRLM01;g__JAISOW01;s__JAISOW01 sp031275345
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Opitutales;f__LL51;g__JAIRKQ01;s__JAIRKQ01 sp031269795
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Opitutales;f__LL51;g__JAIDVZ01;s__JAIDVZ01 sp031257495
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Opitutales;f__UBA9783;g__CABUVL01;s__CABUVL01 sp031278975
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Opitutales;f__UBA9783;g__CABUVL01;s__CABUVL01 sp031258545
#
# Need different family level representatives for f__JAIRLM01, f__LL51, f__UBA9783

# %%
verruco_df = gtdb_df.loc[gtdb_df['gtdb_taxonomy'].str.contains('p__Verrucomicrobiota;') &
                                      (gtdb_df['checkm_completeness'] >= 90) & (gtdb_df['checkm_contamination'] <= 5) & 
                                      (gtdb_df['checkm2_completeness'] >= 90) & (gtdb_df['checkm2_contamination'] <= 5) &
                                      (gtdb_df['checkm_strain_heterogeneity'] == 0)]



# split gtdb taxonomy
verruco_df[['domain','phylum','class','order','family','genus','species']]=verruco_df['gtdb_taxonomy'].str.split(';', expand = True)

# sort the columns to select genus reps
verruco_df.sort_values(by=['genus','gtdb_type_species_of_genus','mimag_high_quality','checkm2_completeness','checkm2_contamination'],
                                  ascending=[True,False,False,False,True], inplace=True)
print(verruco_df)

# %%
# select 1 class level rep for each class (except c__Verrucomicrobiae)
verruco_class_reps_df = verruco_df.loc[~verruco_df['class'].str.contains('c__Verrucomicrobiae')].groupby('class').first().reset_index()
print(verruco_class_reps_df)

# %%
# select 2 order level rep for each order (except o__Opitutales)
verruco_order_reps_df =  verruco_df.drop_duplicates('family', keep='first') \
.loc[verruco_df['class'].str.contains('c__Verrucomicrobiae') & ~verruco_df['order'].str.contains('o__Opitutales')] \
.groupby('order').head(2).reset_index()
print(verruco_order_reps_df)
# Out:
#      index           accession  ambiguous_bases  checkm2_completeness  \
# 0   423244  GB_GCA_018652875.1                0                 94.24
# 1   550574  GB_GCA_019244415.1                0                 92.57
# 2    67043  RS_GCF_000020225.1                0                100.00
# 3   362903  GB_GCA_913048455.1                0                 97.68
# 4   177008  GB_GCA_945861535.1                0                 96.56
# 5    11951  GB_GCA_016871575.1                0                 95.37
# 6    73552  GB_GCA_026397915.1                0                 94.14
# 7   205013  GB_GCA_028293625.1                0                 96.40
# 8   329145  GB_GCA_945877805.1                0                 96.12
# 9   220658  GB_GCA_020718645.1                0                 94.06
# 10  438743  RS_GCF_900105685.1                0                 99.92
# 11  105369  GB_GCA_020849895.1                0                 94.39
# 12  211635  GB_GCA_026646655.1                0                 94.29
#
#     checkm2_contamination checkm2_model  checkm_completeness  \
# 0                    1.90       General                97.97
# 1                    2.17       General                96.13
# 2                    0.25      Specific                97.96
# 3                    0.96       General                99.32
# 4                    1.92       General                98.65
# 5                    0.87       General                96.62
# 6                    0.86       General                95.91
# 7                    1.85       General                97.97
# 8                    1.94       General                97.30
# 9                    0.20       General                98.65
# 10                   0.16      Specific                99.32
# 11                   0.16       General                96.62
# 12                   1.89       General                97.97
#
#     checkm_contamination  checkm_marker_count  checkm_marker_lineage  ...  \
# 0                   0.84                  230  k__Bacteria (UID2982)  ...
# 1                   1.35                  230  k__Bacteria (UID2982)  ...
# 2                   0.00                  229  k__Bacteria (UID2982)  ...
# 3                   0.68                  229  k__Bacteria (UID2982)  ...
# 4                   2.03                  230  k__Bacteria (UID2982)  ...
# 5                   2.39                  230  k__Bacteria (UID2982)  ...
# 6                   0.71                  230  k__Bacteria (UID2982)  ...
# 7                   1.38                  230  k__Bacteria (UID2982)  ...
# 8                   0.90                  230  k__Bacteria (UID2982)  ...
# 9                   2.70                  230  k__Bacteria (UID2982)  ...
# 10                  4.39                  230  k__Bacteria (UID2982)  ...
# 11                  0.68                  230  k__Bacteria (UID2982)  ...
# 12                  3.38                  230  k__Bacteria (UID2982)  ...
#
#     trna_aa_count  trna_count  trna_selenocysteine_count       domain  \
# 0              17          37                          1  d__Bacteria
# 1              19          47                          0  d__Bacteria
# 2              19          52                          0  d__Bacteria
# 3              19          42                          2  d__Bacteria
# 4              19          55                          0  d__Bacteria
# 5              19          48                          0  d__Bacteria
# 6              19          47                          1  d__Bacteria
# 7              19          46                          0  d__Bacteria
# 8              19          42                          0  d__Bacteria
# 9              18          42                          0  d__Bacteria
# 10             19          47                          0  d__Bacteria
# 11             19          41                          0  d__Bacteria
# 12             18          43                          0  d__Bacteria
#
#                   phylum                class                   order  \
# 0   p__Verrucomicrobiota  c__Verrucomicrobiae       o__Limisphaerales
# 1   p__Verrucomicrobiota  c__Verrucomicrobiae   o__Chthoniobacterales
# 2   p__Verrucomicrobiota  c__Verrucomicrobiae   o__Verrucomicrobiales
# 3   p__Verrucomicrobiota  c__Verrucomicrobiae   o__Verrucomicrobiales
# 4   p__Verrucomicrobiota  c__Verrucomicrobiae       o__Limisphaerales
# 5   p__Verrucomicrobiota  c__Verrucomicrobiae           o__Palsa-1439
# 6   p__Verrucomicrobiota  c__Verrucomicrobiae           o__Palsa-1439
# 7   p__Verrucomicrobiota  c__Verrucomicrobiae   o__Chthoniobacterales
# 8   p__Verrucomicrobiota  c__Verrucomicrobiae  o__Methylacidiphilales
# 9   p__Verrucomicrobiota  c__Verrucomicrobiae             o__JADLBR01
# 10  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Methylacidiphilales
# 11  p__Verrucomicrobiota  c__Verrucomicrobiae             o__JABWAM01
# 12  p__Verrucomicrobiota  c__Verrucomicrobiae             o__JADLBR01
#
#                     family           genus                     species
# 0            f__AAA164-E04   g__AAA164-E04   s__AAA164-E04 sp000383715
# 1              f__UBA10450         g__AV69         s__AV69 sp019244415
# 2       f__Akkermansiaceae  g__Akkermansia  s__Akkermansia muciniphila
# 3                f__DEV007  g__Arctic95D-9  s__Arctic95D-9 sp002323995
# 4                f__BJHT01       g__BJHT01       s__BJHT01 sp945861535
# 5            f__Palsa-1439     g__CAIKAP01     s__CAIKAP01 sp016871575
# 6              f__CAIQCK01     g__CAIQCK01     s__CAIQCK01 sp026397915
# 7   f__Chthoniobacteraceae     g__CAIURC01     s__CAIURC01 sp028293625
# 8              f__CAMAQI01     g__CAMAQI01     s__CAMAQI01 sp945877805
# 9              f__JAIBCM01       g__DYRQ01       s__DYRQ01 sp020718645
# 10               f__GAS474       g__GAS474       s__GAS474 sp900105685
# 11             f__JABWAM01     g__JABWAM01     s__JABWAM01 sp020849895
# 12             f__JADLBR01     g__JADLBR01     s__JADLBR01 sp020847615
#
# [13 rows x 121 columns]

# %%
verruco_family_reps_df_best = verruco_df.drop_duplicates('gtdb_taxonomy', keep='first') \
.loc[verruco_df['class'].str.contains('c__Verrucomicrobiae') & verruco_df['order'].str.contains('o__Opitutales') & ~verruco_df['family'].str.contains('f__T3Sed10-336')] \
.groupby('family').head(3).reset_index()

print(verruco_family_reps_df_best)

# %%
verruco_family_reps_df_genus = verruco_df.drop_duplicates('genus', keep='first') \
.loc[verruco_df['class'].str.contains('c__Verrucomicrobiae') & verruco_df['order'].str.contains('o__Opitutales') & ~verruco_df['family'].str.contains('f__T3Sed10-336')] \
.groupby(['family']).head(3).reset_index()
# .groupby(['family'], as_index=False, group_keys=False,
#          ).apply(
#              lambda x: x.sample(min(3,len(x)))
#          ).reset_index()

print(verruco_family_reps_df_genus)

# %%
# concatenate in order of unique genera and then best representative. That way in the group, there's unique genera first in each group. If not 3 unique then takes the next best representative for the family
df_merge_verrcu_family = pd.concat([verruco_family_reps_df_genus,verruco_family_reps_df_best]).drop_duplicates('species') \
.groupby('family',sort=False).head(2) \
.sort_values(by=['family','genus']) \
.drop(['index'],axis=1).reset_index()

print(df_merge_verrcu_family)
# Out:
#     index           accession  ambiguous_bases  checkm2_completeness  \
# 0       4  GB_GCA_934660865.1                0                 96.54
# 1       6  GB_GCA_949287935.1                0                 95.67
# 2       3  GB_GCA_913049555.1                0                 95.29
# 3       8  GB_GCA_001872735.1                7                 98.92
# 4       9  RS_GCF_016595555.1                0                 97.63
# 5      23  GB_GCA_030432235.1                0                 95.91
# 6      10  RS_GCF_000025905.1                0                100.00
# 7      11  RS_GCF_027257905.1                0                 99.88
# 8      14  GB_GCA_018673815.1                0                 97.28
# 9      21  GB_GCA_913048125.1                0                 91.60
# 10     15  GB_GCA_013215165.1                0                 97.24
# 11     21  GB_GCA_028280845.1                0                 97.74
# 12     22  GB_GCA_028285755.1                0                 97.16
# 13     20  GB_GCA_029548565.1                0                 97.07
# 14     13  GB_GCA_027622665.1                0                 93.53
# 15     24  GB_GCA_943789185.1                0                 90.15
# 16     16  GB_GCA_020831585.1                0                 98.50
# 17     17  GB_GCA_020831485.1                0                 96.82
# 18      0  GB_GCA_903920165.1                0                 92.24
# 19      1  GB_GCA_018239845.1                0                 99.05
# 20     28  GB_GCA_002388665.1                0                 99.29
# 21     33  GB_GCA_913056175.1                0                 96.49
# 22     31  GB_GCA_002336265.1                0                 95.28
# 23     18  GB_GCA_021772565.1                0                 95.34
# 24     19  GB_GCA_021772515.1                0                 93.77
# 25     32  GB_GCA_014529665.2                0                 97.80
# 26     36  GB_GCA_022824405.1                0                 96.23
# 27     33  GB_GCA_937919465.1                0                 98.07
# 28      5  GB_GCA_031285745.1                0                 92.19
# 29      7  GB_GCA_945957395.1                0                 96.11
#
#     checkm2_contamination checkm2_model  checkm_completeness  \
# 0                    0.03       General                95.27
# 1                    0.00       General                94.59
# 2                    0.84       General                95.00
# 3                    0.00       General                95.27
# 4                    0.15       General               100.00
# 5                    1.26       General               100.00
# 6                    0.01      Specific                99.77
# 7                    0.00       General               100.00
# 8                    1.12       General                98.65
# 9                    0.62       General                94.44
# 10                   0.12       General                98.65
# 11                   1.52       General                98.65
# 12                   0.27       General                99.32
# 13                   0.40       General                93.92
# 14                   0.13       General                95.23
# 15                   0.77       General                96.58
# 16                   0.05       General                99.32
# 17                   0.46       General                98.31
# 18                   0.58       General                92.24
# 19                   0.78       General                98.63
# 20                   0.16       General                98.42
# 21                   0.07       General                97.30
# 22                   0.01       General                90.37
# 23                   0.37       General                93.92
# 24                   0.26       General                95.95
# 25                   0.66       General                99.77
# 26                   0.05       General                96.62
# 27                   0.72       General                97.64
# 28                   0.86       General                91.89
# 29                   0.14       General                99.32
#
#     checkm_contamination  checkm_marker_count  checkm_marker_lineage  ...  \
# 0                   1.69                  230  k__Bacteria (UID2982)  ...
# 1                   0.68                  230  k__Bacteria (UID2982)  ...
# 2                   1.35                  230  k__Bacteria (UID2982)  ...
# 3                   0.00                  230  k__Bacteria (UID2982)  ...
# 4                   1.69                  230  k__Bacteria (UID2982)  ...
# 5                   1.22                  230  k__Bacteria (UID2982)  ...
# 6                   0.00                  230  k__Bacteria (UID2982)  ...
# 7                   0.00                  230  k__Bacteria (UID2982)  ...
# 8                   0.68                  230  k__Bacteria (UID2982)  ...
# 9                   2.09                  230  k__Bacteria (UID2982)  ...
# 10                  1.35                  230  k__Bacteria (UID2982)  ...
# 11                  1.69                  230  k__Bacteria (UID2982)  ...
# 12                  0.00                  230  k__Bacteria (UID2982)  ...
# 13                  2.36                  230  k__Bacteria (UID2982)  ...
# 14                  0.00                  230  k__Bacteria (UID2982)  ...
# 15                  0.00                  230  k__Bacteria (UID2982)  ...
# 16                  0.68                  230  k__Bacteria (UID2982)  ...
# 17                  0.68                  230  k__Bacteria (UID2982)  ...
# 18                  1.37                  227  k__Bacteria (UID2982)  ...
# 19                  0.68                  227  k__Bacteria (UID2982)  ...
# 20                  0.00                  230  k__Bacteria (UID2982)  ...
# 21                  1.35                  230  k__Bacteria (UID2982)  ...
# 22                  0.34                  230  k__Bacteria (UID2982)  ...
# 23                  0.68                  230  k__Bacteria (UID2982)  ...
# 24                  0.68                  230  k__Bacteria (UID2982)  ...
# 25                  1.35                  230  k__Bacteria (UID2982)  ...
# 26                  0.00                  230  k__Bacteria (UID2982)  ...
# 27                  2.70                  230  k__Bacteria (UID2982)  ...
# 28                  0.68                  230  k__Bacteria (UID2982)  ...
# 29                  0.68                  230  k__Bacteria (UID2982)  ...
#
#     trna_aa_count  trna_count  trna_selenocysteine_count       domain  \
# 0              19          39                          0  d__Bacteria
# 1              19          42                          0  d__Bacteria
# 2              18          31                          0  d__Bacteria
# 3              19          43                          0  d__Bacteria
# 4              19          44                          0  d__Bacteria
# 5              19          53                          0  d__Bacteria
# 6              19          46                          0  d__Bacteria
# 7              19          45                          0  d__Bacteria
# 8              19          42                          0  d__Bacteria
# 9              13          25                          0  d__Bacteria
# 10             19          38                          1  d__Bacteria
# 11             19          40                          0  d__Bacteria
# 12             19          39                          0  d__Bacteria
# 13             17          40                          0  d__Bacteria
# 14             18          38                          0  d__Bacteria
# 15             18          38                          0  d__Bacteria
# 16             19          44                          0  d__Bacteria
# 17             19          45                          0  d__Bacteria
# 18             17          44                          0  d__Bacteria
# 19             19          42                          0  d__Bacteria
# 20             19          42                          0  d__Bacteria
# 21             19          43                          0  d__Bacteria
# 22             18          31                          0  d__Bacteria
# 23             19          41                          0  d__Bacteria
# 24             19          47                          0  d__Bacteria
# 25             19          40                          0  d__Bacteria
# 26             19          34                          0  d__Bacteria
# 27             19          67                          0  d__Bacteria
# 28             20          35                          0  d__Bacteria
# 29             19          44                          0  d__Bacteria
#
#                   phylum                class          order  \
# 0   p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 1   p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 2   p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 3   p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 4   p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 5   p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 6   p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 7   p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 8   p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 9   p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 10  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 11  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 12  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 13  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 14  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 15  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 16  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 17  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 18  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 19  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 20  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 21  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 22  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 23  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 24  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 25  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 26  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 27  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 28  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
# 29  p__Verrucomicrobiota  c__Verrucomicrobiae  o__Opitutales
#
#                         family                  genus  \
# 0                   f__CAG-312            g__CAKUIA01
# 1                   f__CAG-312            g__CALXQW01
# 2                  f__CAJWYM01            g__CAJWYM01
# 3              f__CG1-02-43-26        g__CG1-02-43-26
# 4           f__Cerasicoccaceae        g__Cerasicoccus
# 5           f__Cerasicoccaceae            g__JAUIHT01
# 6      f__Coraliomargaritaceae    g__Coraliomargarita
# 7      f__Coraliomargaritaceae  g__Coraliomargarita_A
# 8                  f__JABJCN01            g__JABJCN01
# 9                  f__JABJCN01            g__JABJCN01
# 10                 f__JABSRG01            g__JABSRG01
# 11                 f__JABSRG01            g__JANQKZ01
# 12                 f__JAFGAQ01            g__JANQOQ01
# 13                 f__JAKPNF01            g__JAKPNF01
# 14                  f__MB11C04         g__GCA-2730975
# 15                  f__MB11C04             g__MB11C04
# 16  f__Oceanipulchritudinaceae            g__JAFIGE01
# 17  f__Oceanipulchritudinaceae            g__JAFIGG01
# 18              f__Opitutaceae            g__CAIQQB01
# 19              f__Opitutaceae            g__CAIRCN01
# 20         f__Puniceicoccaceae       g__Puniceicoccus
# 21         f__Puniceicoccaceae       g__Puniceicoccus
# 22                  f__UBA1977             g__UBA1977
# 23                  f__UBA2987            g__JAJFLR01
# 24                  f__UBA2987            g__JAJFLU01
# 25                  f__UBA2995             g__UBA2995
# 26                  f__UBA2995             g__UBA2995
# 27                  f__UBA3534             g__UBA3534
# 28                   f__UBA953            g__CALNBE01
# 29                   f__UBA953            g__CAMFKE01
#
#                             species
# 0           s__CAKUIA01 sp934660865
# 1           s__CALXQW01 sp944390805
# 2           s__CAJWYM01 sp913049555
# 3       s__CG1-02-43-26 sp001872735
# 4            s__Cerasicoccus arenae
# 5           s__JAUIHT01 sp030432235
# 6   s__Coraliomargarita akajimensis
# 7       s__Coraliomargarita_A parva
# 8           s__JABJCN01 sp018668635
# 9           s__JABJCN01 sp913048125
# 10          s__JABSRG01 sp013215165
# 11          s__JANQKZ01 sp028280845
# 12          s__JANQOQ01 sp028285755
# 13          s__JAKPNF01 sp029548565
# 14       s__GCA-2730975 sp014382645
# 15           s__MB11C04 sp002477515
# 16          s__JAFIGE01 sp020831585
# 17          s__JAFIGG01 sp020831485
# 18          s__CAIQQB01 sp903873805
# 19          s__CAIRCN01 sp018239845
# 20     s__Puniceicoccus sp002388665
# 21     s__Puniceicoccus sp913056175
# 22           s__UBA1977 sp002313355
# 23          s__JAJFLR01 sp021772565
# 24          s__JAJFLU01 sp021772515
# 25           s__UBA2995 sp014529675
# 26           s__UBA2995 sp022824405
# 27           s__UBA3534 sp002376875
# 28          s__CALNBE01 sp031285745
# 29          s__CAMFKE01 sp945957395
#
# [30 rows x 121 columns]
